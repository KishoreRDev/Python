# %% [markdown]
# # Import Necessary Library

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
mtcars_data = pd.read_csv("mtcars..csv")
mtcars_data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
## Must know 
1. discrete - Countabe, not measurable and not segregated
2. continuous - it has unit, measurable and segregated

# %% [markdown]
# ## 1. Univariate Analysis
#  **Important Charts:**
#  1. histogram
#  2. countplot
#  3. barplot -- no use
#  4. piechart

# %% [markdown]
# ## Bivariate Analysis
#
# 1. Barplot
# 2. Scatterplot

# %% [markdown]
# ## 3. Multivariate Analysis
#
# 1. pariplot
# 2. heatmap

# %% [markdown]
# ## 1.1 Histogram

# %%
plt.hist(x=mtcars_data.mpg)
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.title("MPG Distribution")
plt.show()

# %% [markdown]
# ### 1.2 countplot  -- if you want to distribution of one continuous features you knocking the door of histogram
# if you want to understand data distribution of one discrete data you knocking the door of countplot

# %%
mtcars_data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %% [markdown]
# ### Note
# 1. Matplotlib doesn't have charts which seaborn has.
# 2. Seaborn doesn't have charts which matplotlib has
# 3. Matplotlib and seaborn has same charts

# %%
sns.countplot(data = mtcars_data, x="am", y=None)
# Out:
# <Axes: xlabel='am', ylabel='count'>

# %% [markdown]
# ## STATIC CHARTS VS DYNAMIC CHARTS
# STATIC CHARTS WHICH ARE NOT CHANGING
# DYNAMIC CHARTS WHICH ARE CHANGING

# %% [markdown]
# ### 1.3 Barplot

# %%
plt.bar(data=mtcars_data, x = "mpg", height="am")
# Out:
# <BarContainer object of 32 artists>

# %%
sns.barplot(data=mtcars_data, x = "am", y="mpg")
# Out:
# <Axes: xlabel='am', ylabel='mpg'>

# %% [markdown]
# # 1.4  pie chart
#
# data given in the pie chart
#
# value         counts
# mpg = 12.5      5
# mpg = 15        3
#
# must be discrete data not continuous data

# %%
mtcars_data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
mtcars_data.cyl.value_counts()
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
plt.pie(x = mtcars_data.cyl.value_counts(), labels=["8 cyl", "4 cyl", "6 cyl"], explode=[0.01, 0.01, 0.01], autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ## Bivariate Analysis
#
# 1. Barplot
# 2. Scatterplot

# %% [markdown]
# ### 2.1 Bar plot when we compare more than two features you knowing the door of barplot
#
# x axis discrete y axis is continuous

# %%
sns.barplot(data=mtcars_data, x = "am", y="mpg")
# Out:
# <Axes: xlabel='am', ylabel='mpg'>

# %% [markdown]
# ### 3.2. Scatterplot
#
# continuous data x and y float means continuous
# If you want to compare 2 continuous data you're knocking on the door of a scatterplot

# %%
mtcars_data.head(7)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4

# %%
plt.scatter(x="wt" ,y = "mpg", data= mtcars_data)

# %%
sns.scatterplot(x="wt" ,y = "mpg", data= mtcars_data)
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>

# %% [markdown]
# ## 3. Multivariate Analysis
#
# 1. pariplot
# 2. heatmap

# %%
#### to identify the strength of relationship between 2 features
1. Pearson corr, co- efficient
2. Spearmen corr.coeff

pearson corr
formula 
 -1 to +1

-1 is negative correlation
x is increase y is decrease

x is increase y also increase 
positive correlation

# %%
sns.pairplot(data=mtcars_data)

# %%
mtcars_data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
mtcars_data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 mtcars_data.corr()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:13133, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13129         """  # noqa: E501
#   13130         data = self._get_numeric_data() if numeric_only else self
#   13131         cols = data.columns
#   13132         idx = cols.copy()
# > 13133         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13134
#   13135         if method == "pearson":
#   13136             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2077                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
# ...

# %%
del mtcars_data["model"]

# %%
corr_matrix = mtcars_data.corr().round(2)
corr_matrix
# Out:
#        mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
# mpg   1.00 -0.85 -0.85 -0.78  0.68 -0.87  0.42  0.66  0.60  0.48 -0.55
# cyl  -0.85  1.00  0.90  0.83 -0.70  0.78 -0.59 -0.81 -0.52 -0.49  0.53
# disp -0.85  0.90  1.00  0.79 -0.71  0.89 -0.43 -0.71 -0.59 -0.56  0.39
# hp   -0.78  0.83  0.79  1.00 -0.45  0.66 -0.71 -0.72 -0.24 -0.13  0.75
# drat  0.68 -0.70 -0.71 -0.45  1.00 -0.71  0.09  0.44  0.71  0.70 -0.09
# wt   -0.87  0.78  0.89  0.66 -0.71  1.00 -0.17 -0.55 -0.69 -0.58  0.43
# qsec  0.42 -0.59 -0.43 -0.71  0.09 -0.17  1.00  0.74 -0.23 -0.21 -0.66
# vs    0.66 -0.81 -0.71 -0.72  0.44 -0.55  0.74  1.00  0.17  0.21 -0.57
# am    0.60 -0.52 -0.59 -0.24  0.71 -0.69 -0.23  0.17  1.00  0.79  0.06
# gear  0.48 -0.49 -0.56 -0.13  0.70 -0.58 -0.21  0.21  0.79  1.00  0.27
# carb -0.55  0.53  0.39  0.75 -0.09  0.43 -0.66 -0.57  0.06  0.27  1.00

# %%
sns.heatmap(data = corr_matrix, annot=True)
plt.figure(figsize)

# Can I compare continuous vs  continuous data for a heat map
# Out:
# <Axes: >

# %% [markdown]
# ## Notes
#
# 1. 0 to 0.20 very big correlation
# 2. 0.21 to 0.40 weak correlation
# 3. 0.41 to 0.60 normal/standard correlation
# 4. 0.61 to 0.80 strong correlation
# 5. 0.81 to 1 very strong correlation
