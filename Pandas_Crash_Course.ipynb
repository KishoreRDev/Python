# %% [markdown]
# # Chapter 1 : Getting & Knowing Your Data

# %%
import pandas as pd

order_details = pd.read_csv(filepath_or_buffer= "data.tsv.txt", sep = "\t")
# Insight and meaning full insights 
# insight means the customer already knows the data 
# meaningful insights mean I found out the information the customer did not know about the data

# %%
pd.read_table("data.tsv.txt")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# # 1.1 Perform  Initial Analysis

# %%
# Fucntion ()
# Attribute

# %%
order_details.shape
# Out:
# (4622, 5)

# %% [markdown]
# #### Terminology alert
# * Rows - Observation or Record
# * Columns - Features or Parameters

# %%
order_details.isnull().sum() #chain of commands or chain of functions
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
order_details.dtypes
# Out:
# order_id              int64
# quantity              int64
# item_name               str
# choice_description      str
# item_price              str
# dtype: object

# %%
order_details.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# ## 1.2 Fino Out the items sold in the restaurent

# %%
order_details.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
print(order_details["item_name"].unique())
# Out:
# <StringArray>
# [         'Chips and Fresh Tomato Salsa',
#                                   'Izze',
#                       'Nantucket Nectar',
#  'Chips and Tomatillo-Green Chili Salsa',
#                           'Chicken Bowl',
#                          'Side of Chips',
#                          'Steak Burrito',
#                       'Steak Soft Tacos',
#                    'Chips and Guacamole',
#                   'Chicken Crispy Tacos',
#                     'Chicken Soft Tacos',
#                        'Chicken Burrito',
#                            'Canned Soda',
#                       'Barbacoa Burrito',
#                       'Carnitas Burrito',
#                          'Carnitas Bowl',
#                          'Bottled Water',
#  'Chips and Tomatillo Green Chili Salsa',
#                          'Barbacoa Bowl',
#                                  'Chips',
#                     'Chicken Salad Bowl',
#                             'Steak Bowl',
# ...

# %% [markdown]
# ## 1.3 Give me the list of Top Selling items

# %%
order_details.groupby(by="item_name")["quantity"].sum().sort_values(ascending = False).head(10)
# Out:
# item_name
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chips and Guacamole             506
# Steak Burrito                   386
# Canned Soft Drink               351
# Chips                           230
# Steak Bowl                      221
# Bottled Water                   211
# Chips and Fresh Tomato Salsa    130
# Canned Soda                     126
# Name: quantity, dtype: int64

# %% [markdown]
# ## 1.4 Give me the list of Least Selling items

# %%
order_details.groupby("item_name")["quantity"].sum().sort_values().head()
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Name: quantity, dtype: int64

# %% [markdown]
# # Chapter 2 Data Cleaning

# %%
order_details["item_price"].str.replace("$", "").astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: str

# %%
order_details.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name                 str
# choice_description        str
# item_price            float64
# dtype: object

# %%
order_details["item_price"].str.replace("$", "").astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
order_details.dtypes
# Out:
# order_id              int64
# quantity              int64
# item_name               str
# choice_description      str
# item_price              str
# dtype: object

# %%
order_details["item_price"] = order_details["item_price"].str.replace("$", "").astype(float)

# %%
order_details
order_details.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name                 str
# choice_description        str
# item_price            float64
# dtype: object

# %%
order_details.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %% [markdown]
# ## Task
# 1. Find out the Top 5 selling items that individuals' revenue made
# 2. Total Revenue of top 5 items sold

# %%
order_details["revenue"] = order_details["quantity"] * order_details["item_price"]
print(pd.DataFrame(data = order_details.revenue))

order_details
order_details.groupby("item_name")["revenue"].sum().sort_values(ascending = False).head()

#order_details.groupby(by="item_name").sum().sort_values(by = "item_price",ascending = False).head()
# Out:
#       revenue
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       33.96
# ...       ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
#
# [4622 rows x 1 columns]
# item_name
# Chicken Bowl           8044.63
# Chicken Burrito        6387.06
# Steak Burrito          4236.13
# Steak Bowl             2479.81
# Chips and Guacamole    2475.62
# Name: revenue, dtype: float64

# %% [markdown]
# # Chapter 3 - Pandas Data Structure
#
# * 1D - Series
# * 2D - DataFrame

# %%
pd.Series(data = [0, 2, 5.6])
# Out:
# 0    0.0
# 1    2.0
# 2    5.6
# dtype: float64

# %%
pd.DataFrame(data = {"name" : ["Kishore", "Sowmiya"]})
# Out:
#       name
# 0  Kishore
# 1  Sowmiya

# %%
## Task
1. create a meaningful series
2. create a meaningful dataset using pandas dataframe with dict 5 observation across 6 features

# %% [markdown]
# # Chapter 4 - Filtering & Selection & Sorting

# %%
football_2012_data = pd.read_csv("Euro_2012_stats_TEAM.csv")
football_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_2012_data.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='str')

# %%
pd.set_option('display.max_rows', None)
football_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
filete_euro_data = football_2012_data[["Team", "Goals", "Yellow Cards", "Red Cards"]]
filete_euro_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
filete_euro_data["Yellow Cards"].sort_values()
# Out:
# 0      9
# 1      7
# 2      4
# 3      5
# 4      6
# 5      4
# 6      9
# 7     16
# 8      5
# 9      7
# 10    12
# 11     6
# 12     6
# 13    11
# 14     7
# 15     5
# Name: Yellow Cards, dtype: int64

# %%
filete_euro_data.sort_values("Yellow Cards", ascending = False)
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 7                 Italy      6            16          0
# 10             Portugal      6            12          0
# 13                Spain     12            11          0
# 0               Croatia      4             9          0
# 6                Greece      5             9          1
# 14               Sweden      5             7          0
# 9                Poland      2             7          1
# 1        Czech Republic      4             7          0
# 12               Russia      5             6          0
# 11  Republic of Ireland      1             6          1
# 4                France      3             6          0
# 3               England      5             5          0
# 8           Netherlands      2             5          0
# 15              Ukraine      2             5          0
# 5               Germany     10             4          0
# 2               Denmark      4             4          0

# %% [markdown]
# ## 4.2 List the team which has got Red Cards

# %%
filete_euro_data["Red Cards"] == 1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Red Cards, dtype: bool

# %%
filete_euro_data[filete_euro_data["Red Cards"] == 1]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %% [markdown]
# ## 4.3 List the team which has gets more that 8 Yello Cards

# %%
filete_euro_data[filete_euro_data["Yellow Cards"] > 8]
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 0    Croatia      4             9          0
# 6     Greece      5             9          1
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0

# %% [markdown]
# ## Task
#
# 1. Find out 5 new quesitions along with script answer

# %% [markdown]
# # Level 1

# %% [markdown]
# ## Chapter 5 - How to deal with missing values

# %%
import pandas as pd

employee_data = pd.read_excel("employee_data.xlsx")
print(employee_data)
# Out:
#       Name   Age Department   Salary            Join_Date
# 0   Rajesh  29.0        Ops  60000.0           21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  2020-12-11 00:00:00
# 2  Mathiew   NaN    Support  58000.0           15-01-2025
# 3  Gilbert  29.0        Ops  60000.0           21-05-2021
# 4    Kevin  28.0    Support  61000.0           30-07-2024
# 5    Navin  35.0    Support  72000.0           19-08-2023
# 6      NaN  40.0         IT  64000.0  2022-10-09 00:00:00
# 7    Nasir  31.0    IT Tech      NaN  2020-12-11 00:00:00

# %% [markdown]
# ## Step 1: i will call to my client, and check with his if he can give the rigth data
#
# Incase client asking us to perform the data cleaning operation

# %%
employee_data.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        2
# Join_Date     0
# dtype: int64

# %%
employee_data.dtypes
# Out:
# Name              str
# Age           float64
# Department        str
# Salary        float64
# Join_Date      object
# dtype: object

# %%
employee_data.describe(include="all")
# Out:
#          Name        Age Department        Salary            Join_Date
# count       7   7.000000          8      6.000000                    8
# unique      6        NaN          4           NaN                    7
# top     Nasir        NaN    Support           NaN  2020-12-11 00:00:00
# freq        2        NaN          3           NaN                    2
# mean      NaN  31.857143        NaN  62500.000000                  NaN
# std       NaN   4.259443        NaN   5049.752469                  NaN
# min       NaN  28.000000        NaN  58000.000000                  NaN
# 25%       NaN  29.000000        NaN  60000.000000                  NaN
# 50%       NaN  31.000000        NaN  60500.000000                  NaN
# 75%       NaN  33.000000        NaN  63250.000000                  NaN
# max       NaN  40.000000        NaN  72000.000000                  NaN

# %%
employee_data.shape
# Out:
# (8, 5)

# %%
employee_data.drop_duplicates(inplace= True)
employee_data
# Out:
#       Name   Age Department   Salary            Join_Date
# 0   Rajesh  29.0        Ops  60000.0           21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  2020-12-11 00:00:00
# 2  Mathiew   NaN    Support  58000.0           15-01-2025
# 3  Gilbert  29.0        Ops  60000.0           21-05-2021
# 4    Kevin  28.0    Support  61000.0           30-07-2024
# 5    Navin  35.0    Support  72000.0           19-08-2023
# 6      NaN  40.0         IT  64000.0  2022-10-09 00:00:00

# %%
# After duplicate removers

employee_data.shape
# Out:
# (7, 5)

# %%
employee_data.dropna(inplace = True)
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
employee_data.shape
# Out:
# (4, 5)

# %% [markdown]
# #### step 3 :Record in a docuement
#
# The client gave a total of 7 observations or records with 5 parameters and 7 out of which 3 entries are removed because those records
# Don't have complete information

# %% [markdown]
# #### Step 4 Get Approval
# * Send this to client and get approval to proceed for model building or model training

# %%
employee_data.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Join_Date     0
# dtype: int64

# %% [markdown]
# # Level 2 Data Cleaning

# %%
import pandas as pd

employee_added_details =  pd.read_excel("employee_data.xlsx" , sheet_name = "More Employee")
employee_added_details
# Out:
#              Name Age Department Salary            Join_Date
# 0          Rajesh  29        Ops  60000          21-05-2023
# 1           Nasir  31    IT Tech  62000  2020-12-11 00:00:00
# 2         Mathiew   —    Support  58000          15-01-2025
# 3         Gilbert  29        Ops  60000          21-05-2021
# 4           Kevin  28    Support  61000          30-07-2024
# 5           Navin  35    Support  72000          19-08-2023
# 6               —  40    IT Tech  64000  2022-10-09 00:00:00
# 7          Roshan  31    IT Tech      —  2020-12-11 00:00:00
# 8       Kuppusamy  28        Ops      —          21-05-2021
# 9           Ajesh  28    Support      —          30-07-2024
# 10           Diya  31    IT Tech  63000  2020-12-11 00:00:00
# 11        Mathiew   —    Support  58000          15-01-2025
# 12  Jagadheeswari  28    IT Tech      —                   —
# 13           Mani  28        Ops      —          21-05-2021

# %%
employee_added_details.shape
# Out:
# (14, 5)

# %% [markdown]
# #### Step 1: Drop Duplicates

# %%
employee_added_details.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# dtype: bool

# %%
employee_added_details.drop_duplicates(inplace=True)
employee_added_details
# Out:
#              Name Age Department Salary            Join_Date
# 0          Rajesh  29        Ops  60000          21-05-2023
# 1           Nasir  31    IT Tech  62000  2020-12-11 00:00:00
# 2         Mathiew   —    Support  58000          15-01-2025
# 3         Gilbert  29        Ops  60000          21-05-2021
# 4           Kevin  28    Support  61000          30-07-2024
# 5           Navin  35    Support  72000          19-08-2023
# 6               —  40    IT Tech  64000  2022-10-09 00:00:00
# 7          Roshan  31    IT Tech      —  2020-12-11 00:00:00
# 8       Kuppusamy  28        Ops      —          21-05-2021
# 9           Ajesh  28    Support      —          30-07-2024
# 10           Diya  31    IT Tech  63000  2020-12-11 00:00:00
# 12  Jagadheeswari  28    IT Tech      —                   —
# 13           Mani  28        Ops      —          21-05-2021

# %% [markdown]
# #### Step 2 Identify null Entries

# %%
import numpy as np

employee_added_details.replace("—", np.nan, inplace= True)
employee_added_details.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        5
# Join_Date     0
# dtype: int64

# %% [markdown]
# #### Step 3 : Go for best Imputation

# %%
employee_added_details["Department"].unique()
# Out:
# <StringArray>
# ['Ops', 'IT Tech', 'Support']
# Length: 3, dtype: str

# %%
employee_added_details["Department"] == "Support"
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 12    False
# 13    False
# Name: Department, dtype: bool

# %%
employee_added_details[employee_added_details["Department"] == "Support"]
# Out:
#       Name  Age Department Salary    Join_Date
# 2  Mathiew  NaN    Support  58000  15-01-2025
# 4    Kevin   28    Support  61000  30-07-2024
# 5    Navin   35    Support  72000  19-08-2023
# 9    Ajesh   28    Support    NaN  30-07-2024

# %%
employee_added_details[employee_added_details["Department"] == "IT Tech"]
# Out:
#              Name Age Department Salary            Join_Date
# 1           Nasir  31    IT Tech  62000  2020-12-11 00:00:00
# 6             NaN  40    IT Tech  64000  2022-10-09 00:00:00
# 7          Roshan  31    IT Tech    NaN  2020-12-11 00:00:00
# 10           Diya  31    IT Tech  63000  2020-12-11 00:00:00
# 12  Jagadheeswari  28    IT Tech    NaN                   —

# %%
employee_added_details[employee_added_details["Department"] == "Ops"]
# Out:
#          Name Age Department Salary    Join_Date
# 0      Rajesh  29        Ops  60000  21-05-2023
# 3     Gilbert  29        Ops  60000  21-05-2021
# 8   Kuppusamy  28        Ops    NaN  21-05-2021
# 13       Mani  28        Ops    NaN  21-05-2021

# %% [markdown]
# ### Data Analytics Task
# 1. Impute The relevant value in the salary column wherever it is Nan, based on department
# 2. Impute Mathew's age as 27

# %%
employee_added_details[employee_added_details["Department"] == "Support"]
# Out:
#       Name  Age Department Salary    Join_Date
# 2  Mathiew  NaN    Support  58000  15-01-2025
# 4    Kevin   28    Support  61000  30-07-2024
# 5    Navin   35    Support  72000  19-08-2023
# 9    Ajesh   28    Support    NaN  30-07-2024

# %%
employee_added_details[(employee_added_details["Department"] == "Support") & (employee_added_details["Salary"].isna())]
# Out:
#     Name Age Department Salary    Join_Date
# 9  Ajesh  28    Support    NaN  30-07-2024

# %%
employee_added_details[(employee_added_details["Department"] == "Support") & (employee_added_details["Salary"].isna())]
employee_added_details.loc[(employee_added_details["Department"] == "Support") & (employee_added_details["Salary"].isna()),"Salary"] = 61000

employee_added_details
# Out:
#              Name  Age Department Salary            Join_Date
# 0          Rajesh   29        Ops  60000          21-05-2023
# 1           Nasir   31    IT Tech  62000  2020-12-11 00:00:00
# 2         Mathiew  NaN    Support  58000          15-01-2025
# 3         Gilbert   29        Ops  60000          21-05-2021
# 4           Kevin   28    Support  61000          30-07-2024
# 5           Navin   35    Support  72000          19-08-2023
# 6             NaN   40    IT Tech  64000  2022-10-09 00:00:00
# 7          Roshan   31    IT Tech    NaN  2020-12-11 00:00:00
# 8       Kuppusamy   28        Ops    NaN          21-05-2021
# 9           Ajesh   28    Support  61000          30-07-2024
# 10           Diya   31    IT Tech  63000  2020-12-11 00:00:00
# 12  Jagadheeswari   28    IT Tech    NaN                   —
# 13           Mani   28        Ops    NaN          21-05-2021
