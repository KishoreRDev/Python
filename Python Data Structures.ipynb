# %% [markdown]
# # Build in Data Structures

# %% [markdown]
# ## List

# %%
empty_cart = []
print(empty_cart)
type(empty_cart)
# Out:
# []
# list

# %%
items_to_buy = ["Apple", "Orange", "Grapes", "Pomogranate", "Apple", 6.5, 7]
print(items_to_buy)

# %%
items_to_buy[3]
# Out:
# 'Pomogranate'

# %%
items_to_buy[1:5]
# Out:
# ['Orange', 'Grapes', 'Pomogranate', 'Apple']

# %%
items_to_buy[-3 : -1]
# Out:
# ['Apple', 6.5]

# %%
items_to_buy[1] = "Mango"
items_to_buy
# Out:
# ['Apple', 'Mango', 'Grapes', 'Pomogranate', 'Apple', 6.5, 7]

# %%
items_to_buy.insert(1, "Banana")
items_to_buy
# Out:
# ['Apple', 'Banana', 'Mango', 'Grapes', 'Pomogranate', 'Apple', 6.5, 7]

# %% [markdown]
# ## Sets

# %%
items_to_buy2 = set()
items_to_buy2
# Out:
# set()

# %%
items_to_buy2 = {"Apple", "Orange", "Grapes", "Pomogranate", "Apple", 6.5, 7}
print(items_to_buy2)
# Out:
# {'Orange', 7, 6.5, 'Pomogranate', 'Grapes', 'Apple'}

# %%
items_to_buy2.add("Mango")
items_to_buy2
# Out:
# {6.5, 7, 'Apple', 'Grapes', 'Mango', 'Orange', 'Pomogranate'}

# %%
items_to_buy2.discard("Grapes")
items_to_buy2
# Out:
# {6.5, 7, 'Apple', 'Mango', 'Orange', 'Pomogranate'}

# %% [markdown]
# # Tuple

# %%
empty_cart_3 = ()
empty_cart_3
# Out:
# ()

# %%
type(empty_cart_3)
# Out:
# tuple

# %%
items_to_buy3 = ("Apple", "Orange", "Grapes", "Pomogranate", "Apple", 6.5, 7)
print(items_to_buy3)
# Out:
# ('Apple', 'Orange', 'Grapes', 'Pomogranate', 'Apple', 6.5, 7)

# %%
items_to_buy3[0]
# Out:
# 'Apple'

# %%
items_to_buy3[0:3]
# Out:
# ('Apple', 'Orange', 'Grapes')

# %%
items_to_buy3[-3:-1]
# Out:
# ('Apple', 6.5)

# %%
items_to_buy3[0] = "banana"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 items_to_buy3[0] = "banana"
#
# TypeError: 'tuple' object does not support item assignment

# %%
items_to_buy3.count("Orange")
# Out:
# 1

# %% [markdown]
# # Dictionary

# %%
dic = {}
dic
# Out:
# {}

# %%
empty_cart_4 = {}
empty_cart_4
# Out:
# {}

# %%
type(empty_cart_4)
# Out:
# dict

# %%
student_marks = { "Maths": 86,
                  "English": 56,
                  "Science" : 80
}
student_marks
# Out:
# {'Maths': 86, 'English': 56, 'Science': 80}

# %%
items_to_buy4 = {"Potato":5, "Tomato":2, "Apple": 2.5, "Potato":10}
items_to_buy4
# Out:
# {'Potato': 10, 'Tomato': 2, 'Apple': 2.5}

# %%
items_to_buy4.get("Potato")
# Out:
# 10

# %%
items_to_buy4.keys()
# Out:
# dict_keys(['Potato', 'Tomato', 'Apple'])

# %%
items_to_buy4.items()
# Out:
# dict_items([('Potato', 10), ('Tomato', 2), ('Apple', 2.5)])

# %%
import pandas as pd

pd.DataFrame(data=items_to_buy4, index =0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 import pandas as pd
#       2
# ----> 3 pd.DataFrame(data=items_to_buy4, index =0)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
student_marks = {"Student_name": ["Ram", "Suresh", "Mohan"], "English ":[50, 95, 40], "Tamil": [45, 80, 92],
                 "Maths":[70, 80, 92]}
pd.DataFrame(data = student_marks)
# Out:
#   Student_name  English   Tamil  Maths
# 0          Ram        50     45     70
# 1       Suresh        95     80     80
# 2        Mohan        40     92     92

# %%
pd.Data
