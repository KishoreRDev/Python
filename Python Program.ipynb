# %% [markdown]
# # Number Guessing Game Level 0

# %%
print ("""Instructions
Enter the range of numbers you want the target number to be between, and press New Target
Enter your guess
See if your guess is too high or too low
Change your guess
The app will tell you when you are right, and how many guesses you had """)
# Out:
# Instructions
# Enter the range of numbers you want the target number to be between, and press New Target
# Enter your guess
# See if your guess is too high or too low
# Change your guess
# The app will tell you when you are right, and how many guesses you had

# %%
secret_number = 56
print(secret_number)
user_input = int(input("Enter Your Guessing Number : "))

if user_input == secret_number:
    print("Congradulations! you are guess correct number")
else:
    print("Sorry please retry")
# Out:
# 56
# Enter Your Guessing Number :  45
# Sorry please retry

# %% [markdown]
# # Level 2

# %%
secret_number = 56

for i in range(7):
    user_input = int(input("Enter Your Guessing Number : "))
    if user_input == secret_number:
        print("Congradulations! you are guess correct number")
        break
    else:
        print("Sorry please retry")
# Out:
# Enter Your Guessing Number :  56
# Congradulations! you are guess correct number

# %%
# while loop
secret_number = 56

while True:
    user_input = int(input("Enter Your Guessing Number : "))
    if user_input == secret_number:
        print("Congradulations! you are guess correct number")
        break
    else:
        print("Sorry please retry")
# Out:
# Enter Your Guessing Number :  453
# Sorry please retry
# Enter Your Guessing Number :  53
# Sorry please retry
# Enter Your Guessing Number :  5
# Sorry please retry
# Enter Your Guessing Number :  65
# Sorry please retry
# Enter Your Guessing Number :  56
# Congradulations! you are guess correct number

# %%
# Condtions add for invalid number 

secret_number = 56
for i in range(1, 8):
    user_input = int(input("Enter Your Guessing Number : "))
    if user_input < 0 or user_input > 100:
        print ("Please Enter a number between 1 to 100")
    elif user_input > secret_number:
        print ("Your Guessed Number is Greater than Secret Number")
    elif user_input < secret_number:
        print ("Your Guessed Number is Lesser than Secret Number")
    elif user_input == secret_number:
        break
    else:
        print("Sorry please retry")
if user_input == secret_number:
     print("Congradulations! you are guess correct number : ", secret_number, "in", i, "attempts") 
else:
    print("You are using all 7 trails")

# %%
# Secret Number should be random
import random 


secret_number = random.randint(1, 100) 
for i in range(1, 8):
    try:        
        user_input = int(input("Enter Your Guessing Number : "))
        if user_input < 0 or user_input > 100:
            print ("Please Enter a number between 1 to 100")
        elif user_input > secret_number:
            print ("Your Guessed Number is Greater than Secret Number")
        elif user_input < secret_number:
            print ("Your Guessed Number is Lesser than Secret Number")
        elif user_input == secret_number:
            break
        else:
            print("Sorry please retry")
    except Exception as e:
        print(e)
if user_input == secret_number:
     print("Congradulations! you are guess correct number : ", secret_number, "in", i, "attempts") 
else:
    print("You are using all 7 trails")
# Out:
# Enter Your Guessing Number :  fds
# invalid literal for int() with base 10: 'fds'
# Enter Your Guessing Number :   45
# Your Guessed Number is Greater than Secret Number
# Enter Your Guessing Number :  45
# Your Guessed Number is Greater than Secret Number
# Enter Your Guessing Number :  20
# Your Guessed Number is Lesser than Secret Number
# Enter Your Guessing Number :  35
# Your Guessed Number is Greater than Secret Number
# Enter Your Guessing Number :  30
# Your Guessed Number is Greater than Secret Number
# Enter Your Guessing Number :  26
# Your Guessed Number is Greater than Secret Number
# You are using all 7 trails

# %%
def number_guessing_game():
# Secret Number should be random
    import random 
    
    
    secret_number = random.randint(1, 100) 
    for i in range(1, 8):
        try:        
            user_input = int(input("Enter Your Guessing Number : "))
            if user_input < 0 or user_input > 100:
                print ("Please Enter a number between 1 to 100")
            elif user_input > secret_number:
                print ("Your Guessed Number is Greater than Secret Number")
            elif user_input < secret_number:
                print ("Your Guessed Number is Lesser than Secret Number")
            elif user_input == secret_number:
                break
            else:
                print("Sorry please retry")
        except Exception as e:
            print(e)
    if user_input == secret_number:
         print("Congradulations! you are guess correct number : ", secret_number, "in", i, "attempts") 
    else:
        print("You are using all 7 trails")
# Out:
# Enter Your Guessing Number :  45
# Your Guessed Number is Lesser than Secret Number
# Enter Your Guessing Number :  54
# Your Guessed Number is Lesser than Secret Number
# Enter Your Guessing Number :  54
# Your Guessed Number is Lesser than Secret Number
# Enter Your Guessing Number :
# invalid literal for int() with base 10: ''
# Enter Your Guessing Number :  5
# Your Guessed Number is Lesser than Secret Number
# Enter Your Guessing Number :  445
# Please Enter a number between 1 to 100
# Enter Your Guessing Number :  54
# Your Guessed Number is Lesser than Secret Number
# You are using all 7 trails

# %%
number_guessing_game()
# Out:
# Enter Your Guessing Number :  45
# Congradulations! you are guess correct number :  45 in 1 attempts
